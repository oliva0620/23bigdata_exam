# %% [markdown]
# <a href="https://colab.research.google.com/github/oliva0620/biddata_exam/blob/main/Pandas_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame([[1, 2, 3, 4],
                   [2, np.nan, 4, 5], 
                   [3, 4, 5, 6]], index=list('가나다'), columns=list('ABCD'))
df
# Out:
#    A    B  C  D
# 가  1  2.0  3  4
# 나  2  NaN  4  5
# 다  3  4.0  5  6

# %%
df.sum(axis=0)
# Out:
# A     6.0
# B     6.0
# C    12.0
# D    15.0
# dtype: float64

# %%
df.sum(axis=1)
# Out:
# 가    10.0
# 나    11.0
# 다    18.0
# dtype: float64

# %%
df.dropna(axis=0, how='any')
# Out:
#    A    B  C  D
# 가  1  2.0  3  4
# 다  3  4.0  5  6

# %%
df.dropna(axis=1, how='any')
# Out:
#    A  C  D
# 가  1  3  4
# 나  2  4  5
# 다  3  5  6

# %%
df.apply(lambda x: sum(x), axis=0)
# Out:
# A     6.0
# B     NaN
# C    12.0
# D    15.0
# dtype: float64

# %%
df.apply(lambda x: sum(x), axis=1)
# Out:
# 가    10.0
# 나     NaN
# 다    18.0
# dtype: float64
